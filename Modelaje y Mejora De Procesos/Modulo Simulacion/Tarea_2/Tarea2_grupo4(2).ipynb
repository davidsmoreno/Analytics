# %% [markdown]
# # Modelaje y mejora de procesos 2023-2 - Módulo de Simulación
#
# Departamento de Ingeniería Industrial
#
# Universidad de los Andes

# %% [markdown]
# ## Tarea 2- Grupo 4 - Análisis de entrada
# * Luisa María De La Hortúa Pulido 201712785
# * David Santiago Moreno Medina 201728270

# %% [markdown]
# ## Punto 2

# %%
import pandas as pd

df = pd.read_csv('mmps_clase2_datos.csv')
df
# Out:
#       FranjaHoraria  HoraSegundos  TiempoEntreArribos
# 0                 1      0.000000           22.613067
# 1                 1     22.613067           14.997886
# 2                 1     37.610953           29.935142
# 3                 1     67.546095           80.100269
# 4                 1    147.646364           16.247739
# ...             ...           ...                 ...
# 1534              3  10767.001060            5.777145
# 1535              3  10772.778210            7.321550
# 1536              3  10780.099760            5.203301
# 1537              3  10785.303060            5.885214
# 1538              3  10791.188270            5.100616
#
# [1539 rows x 3 columns]

# %% [markdown]
# Cálculo de estadísticas usando pandas.

# %%
print(df.describe())
# Out:
#        FranjaHoraria  HoraSegundos  TiempoEntreArribos
# count    1539.000000   1539.000000         1539.000000
# mean        2.191683   6116.840036            7.015132
# std         0.740986   2813.335515            6.231412
# min         1.000000      0.000000            0.016558
# 25%         2.000000   4054.208265            4.728706
# 50%         2.000000   6201.453567            5.961327
# 75%         3.000000   8471.415347            7.503004
# max         3.000000  10791.188270           80.100269

# %% [markdown]
# Generación de histograma usando matplotlib.

# %%
import matplotlib.pyplot as plt
count, bins, ignored = plt.hist(x=df['TiempoEntreArribos'], bins=30)
plt.title('Histograma de tiempos de arribo')
plt.xlabel('Tiempos de servicio')
plt.ylabel('Frecuencia')
plt.show()

print(bins)
print(count)
# Out:
# [1.65583120e-02 2.68601533e+00 5.35547235e+00 8.02492937e+00
#  1.06943864e+01 1.33638434e+01 1.60333004e+01 1.87027575e+01
#  2.13722145e+01 2.40416715e+01 2.67111285e+01 2.93805855e+01
#  3.20500426e+01 3.47194996e+01 3.73889566e+01 4.00584136e+01
#  4.27278706e+01 4.53973277e+01 4.80667847e+01 5.07362417e+01
#  5.34056987e+01 5.60751558e+01 5.87446128e+01 6.14140698e+01
#  6.40835268e+01 6.67529838e+01 6.94224409e+01 7.20918979e+01
#  7.47613549e+01 7.74308119e+01 8.01002689e+01]
# [165. 401. 653. 204.  16.  23.  17.  15.   6.  11.   6.   2.   3.   3.
#    5.   0.   0.   0.   3.   0.   1.   1.   2.   0.   0.   0.   0.   0.
#    1.   1.]

# %% [markdown]
# # Bondad de ajuste

# %% [markdown]
# Densidad normal estándar.

# %%
from distfit import distfit

# %% [markdown]
# ## Datos  Total

# %%
dfit = distfit(todf=True)
dfit.fit_transform(df['TiempoEntreArribos'])
dfit.plot()
# Out:
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [norm      ] [0.0 sec] [RSS: 0.110063] [loc=7.015 scale=6.229]
# [distfit] >INFO> [expon     ] [0.00 sec] [RSS: 0.142671] [loc=0.017 scale=6.999]
# [distfit] >INFO> [pareto    ] [0.20 sec] [RSS: 0.147156] [loc=-132.877 scale=132.894]
# [distfit] >INFO> [dweibull  ] [0.09 sec] [RSS: 0.0192263] [loc=5.896 scale=2.306]
# [distfit] >INFO> [t         ] [0.07 sec] [RSS: 0.00907101] [loc=5.888 scale=1.638]
# [distfit] >INFO> [genextreme] [0.10 sec] [RSS: 0.0522111] [loc=4.821 scale=2.762]
# [distfit] >INFO> [gamma     ] [0.12 sec] [RSS: 0.317698] [loc=0.017 scale=2.996]
# [distfit] >INFO> [lognorm   ] [0.10 sec] [RSS: 0.115792] [loc=-0.081 scale=4.509]
# [distfit] >INFO> [beta      ] [0.23 sec] [RSS: 0.0633798] [loc=-0.088 scale=50170361260.484]
# [distfit] >INFO> [uniform   ] [0.0 sec] [RSS: 0.228572] [loc=0.017 scale=80.084]
# [distfit] >INFO> [loggamma  ] [0.14 sec] [RSS: 0.113118] [loc=-2263.565 scale=296.297]
# (<Figure size 1440x1080 with 1 Axes>,
#  <Axes: title={'center': '\nt(df=1.57844, loc=5.88836, scale=1.63774)'}, xlabel='Values', ylabel='Frequency'>)

# %%
dfit.plot_summary()
plt.axhline(y = 0.05, color = 'r', linestyle = '-')
plt.show()

# %% [markdown]
# ## Franja 1

# %%
dfit = distfit(todf=True)
dfit.fit_transform(df[df['FranjaHoraria']==1]['TiempoEntreArribos'])
dfit.plot()
# Out:
# [distfit] >INFO> NumExpr defaulting to 8 threads.
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [norm      ] [0.00 sec] [RSS: 0.00345359] [loc=11.885 scale=12.307]
# [distfit] >INFO> [expon     ] [0.00 sec] [RSS: 0.000260775] [loc=0.017 scale=11.868]
# [distfit] >INFO> [pareto    ] [0.04 sec] [RSS: 0.00334149] [loc=-1.751 scale=1.767]
# [distfit] >INFO> [dweibull  ] [0.08 sec] [RSS: 0.00239933] [loc=8.129 scale=7.823]
# [distfit] >INFO> [t         ] [0.07 sec] [RSS: 0.00211344] [loc=8.177 scale=6.411]
# [distfit] >INFO> [genextreme] [0.14 sec] [RSS: 0.000429723] [loc=5.517 scale=5.384]
# [distfit] >INFO> [gamma     ] [0.12 sec] [RSS: 0.000249852] [loc=0.016 scale=11.604]
# [distfit] >INFO> [lognorm   ] [0.15 sec] [RSS: 0.000339476] [loc=-0.861 scale=8.494]
# [distfit] >INFO> [beta      ] [0.16 sec] [RSS: 0.00107877] [loc=-2.160 scale=2635310772389087.000]
# [distfit] >INFO> [uniform   ] [0.0 sec] [RSS: 0.00821495] [loc=0.017 scale=80.084]
# [distfit] >INFO> [loggamma  ] [0.12 sec] [RSS: 0.00357881] [loc=-4982.725 scale=640.662]
# (<Figure size 1440x1080 with 1 Axes>,
#  <Axes: title={'center': '\ngamma(a=1.02282, loc=0.0155943, scale=11.6042)'}, xlabel='Values', ylabel='Frequency'>)

# %%
dfit.plot_summary()
plt.axhline(y = 0.05, color = 'r', linestyle = '-')
plt.show()

# %% [markdown]
# ### Franja 2

# %%
dfit = distfit(todf=True)
dfit.fit_transform(df[df['FranjaHoraria']==2]['TiempoEntreArribos'])
dfit.plot()
# Out:
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [norm      ] [0.0 sec] [RSS: 0.0170915] [loc=5.646 scale=2.583]
# [distfit] >INFO> [expon     ] [0.0 sec] [RSS: 0.0426648] [loc=1.000 scale=4.646]
# [distfit] >INFO> [pareto    ] [0.05 sec] [RSS: 0.129814] [loc=0.000 scale=1.000]
# [distfit] >INFO> [dweibull  ] [0.04 sec] [RSS: 0.0217026] [loc=5.635 scale=2.417]
# [distfit] >INFO> [t         ] [0.12 sec] [RSS: 0.0170909] [loc=5.646 scale=2.583]
# [distfit] >INFO> [genextreme] [0.07 sec] [RSS: 0.0155188] [loc=4.961 scale=2.747]
# [distfit] >INFO> [gamma     ] [0.12 sec] [RSS: 0.0171311] [loc=-141.548 scale=0.045]
# [distfit] >INFO> [lognorm   ] [0.21 sec] [RSS: 0.0173027] [loc=-130.906 scale=136.521]
# [distfit] >INFO> [beta      ] [0.19 sec] [RSS: 0.00298162] [loc=1.000 scale=8.994]
# [distfit] >INFO> [uniform   ] [0.0 sec] [RSS: 0.00338128] [loc=1.000 scale=8.993]
# [distfit] >INFO> [loggamma  ] [0.13 sec] [RSS: 0.0170432] [loc=-138.080 scale=29.509]
# (<Figure size 1440x1080 with 1 Axes>,
#  <Axes: title={'center': '\nbeta(a=1.01244, b=0.962971, loc=0.99997, scale=8.99363)'}, xlabel='Values', ylabel='Frequency'>)

# %%
dfit.plot_summary()
plt.axhline(y = 0.05, color = 'r', linestyle = '-')
plt.show()

# %% [markdown]
# ### Franja 3

# %%
dfit = distfit(todf=True)
dfit.fit_transform(df[df['FranjaHoraria']==3]['TiempoEntreArribos'])
dfit.plot()
# Out:
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [norm      ] [0.0 sec] [RSS: 0.0270254] [loc=6.009 scale=0.988]
# [distfit] >INFO> [expon     ] [0.0 sec] [RSS: 0.637443] [loc=3.321 scale=2.688]
# [distfit] >INFO> [pareto    ] [0.06 sec] [RSS: 0.862207] [loc=-0.015 scale=3.336]
# [distfit] >INFO> [dweibull  ] [0.03 sec] [RSS: 0.0417027] [loc=5.954 scale=0.834]
# [distfit] >INFO> [t         ] [0.10 sec] [RSS: 0.0230988] [loc=5.980 scale=0.912]
# [distfit] >INFO> [genextreme] [0.09 sec] [RSS: 0.00942865] [loc=5.603 scale=0.902]
# [distfit] >INFO> [gamma     ] [0.05 sec] [RSS: 0.01035] [loc=1.348 scale=0.208]
# [distfit] >INFO> [lognorm   ] [0.15 sec] [RSS: 0.00959769] [loc=-0.508 scale=6.443]
# [distfit] >INFO> [beta      ] [0.08 sec] [RSS: 0.0103508] [loc=1.349 scale=820794.538]
# [distfit] >INFO> [uniform   ] [0.00 sec] [RSS: 0.502562] [loc=3.321 scale=6.750]
# [distfit] >INFO> [loggamma  ] [0.13 sec] [RSS: 0.0290592] [loc=-264.815 scale=37.485]
# (<Figure size 1440x1080 with 1 Axes>,
#  <Axes: title={'center': '\ngenextreme(c=0.139874, loc=5.60314, scale=0.902003)'}, xlabel='Values', ylabel='Frequency'>)

# %%
dfit.plot_summary()
plt.axhline(y = 0.05, color = 'r', linestyle = '-')
plt.show()

# %% [markdown]
# ## Punto 3

# %% [markdown]
# ## 1. Distribución Normal
#
# ### Iniciamos generando números aleatorios de acuerdo con una distribución normal.

# %%
import numpy as np
from scipy.stats import norm
n=1000
loc=3
scale=0.5
vals_normal = norm.rvs(loc=loc, scale=scale, size=n)

# %% [markdown]
# ### Ahora calculamos el histograma asociado a los datos y lo graficamos junto con la densidad de la normal.

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm
# histograma
count, bins, ignored = plt.hist(x=vals_normal, bins=30, density=True)

# densidad
nobs = 10000
xmin = min(vals_normal)
xmax = max(vals_normal)
step = (xmax-xmin)/nobs
x= np.arange(xmin,xmax,step)
plt.plot(x, norm.pdf(x,loc=3,scale=0.5))

plt.title('Histograma y densidad')
plt.xlabel('Valores')
plt.ylabel('Densidad')
plt.show()

# %% [markdown]
# ### Para la misma distribución podemos calcular los primeros 4 momentos.

# %%
mean, var, skew, kurt = norm.stats(loc=loc,scale=scale, moments='mvsk')
print("Media: {}".format(mean))
print("Varianza: {}".format(var))
print("Asimetría: {}".format(skew))
print("Curtosis: {}".format(kurt))
# Out:
# Media: 3.0
# Varianza: 0.25
# Asimetría: 0.0
# Curtosis: 0.0

# %% [markdown]
# ### Ahora tomamos los datos generados y los usamos para ajustar los parámetros de una variable normal. Calculamos los momentos de la variable ajustada y mostramos la densidad de ésta contra el histograma de los datos.

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm
# ajuste de datos a una normal - obtener parámetros
floc, fscale = norm.fit(vals_normal)
print("Parámetros de la distribución normal ajustada")
print("Localización: {}".format(floc))
print("Escala: {}".format(fscale))


# variable ajustada 
fitted_var = norm.freeze(loc=floc, scale=fscale)
# momentos de la variable ajustada
mean, var, skew, kurt = fitted_var.stats(moments='mvsk')
print("\nMomentos de la distribución normal ajustada")
print("Media: {}".format(mean))
print("Varianza: {}".format(var))
print("Asimetría: {}".format(skew))
print("Curtosis: {}".format(kurt))


# histograma
count, bins, ignored = plt.hist(x=vals_normal, bins=30, density=True)

# densidad
nobs = 10000
xmin = min(vals_normal)
xmax = max(vals_normal)
step = (xmax-xmin)/nobs
x= np.arange(xmin,xmax,step)
plt.plot(x, fitted_var.pdf(x))

plt.title('Histograma y densidad')
plt.xlabel('Valores')
plt.ylabel('Densidad')
plt.show()
# Out:
# Parámetros de la distribución normal ajustada
# Localización: 2.957218122649301
# Escala: 0.4989904182290631
#
# Momentos de la distribución normal ajustada
# Media: 2.957218122649301
# Varianza: 0.2489914374844153
# Asimetría: 0.0
# Curtosis: 0.0

# %% [markdown]
# ## Distribución Gamma
#
# Repetimos el ejercicio anterior con una distribución Gamma.

# %%
import numpy as np
from scipy.stats import gamma
n=1000
a = 2
loc = 1
vals_gamma = gamma.rvs(a=a, loc=loc, size=n)

# %%
import matplotlib.pyplot as plt
from scipy.stats import gamma
# histograma
count, bins, ignored = plt.hist(x=vals_gamma, bins=30, density=True)

# densidad
nobs = 10000
xmin = min(vals_gamma)
xmax = max(vals_gamma)
step = (xmax-xmin)/nobs
x= np.arange(xmin,xmax,step)
plt.plot(x, gamma.pdf(x, a=a,loc=loc))

plt.title('Histograma y densidad'+' '+'a=1')
plt.xlabel('Valores')
plt.ylabel('Densidad') 
plt.show()

# %%
mean, var, skew, kurt = gamma.stats(a=a,loc=loc, moments='mvsk')
print("Media: {}".format(mean))
print("Varianza: {}".format(var))
print("Asimetría: {}".format(skew))
print("Curtosis: {}".format(kurt))
# Out:
# Media: 3.0
# Varianza: 2.0
# Asimetría: 1.414213562373095
# Curtosis: 3.0

# %%
import matplotlib.pyplot as plt
from scipy.stats import gamma
# ajuste de datos a una gamma - obtener parámetros
fa, floc, fscale = gamma.fit(vals_gamma)
print("Parámetros de la distribución gamma ajustada")
print("a: {}".format(fa))
print("Localización: {}".format(floc))
print("Escala: {}".format(fscale))

# variable ajustada 
fitted_var = gamma.freeze(a=fa,loc=floc,scale=fscale)
# momentos de la variable ajustada
mean, var, skew, kurt = fitted_var.stats(moments='mvsk')
print("\nMomentos de la distribución gamma ajustada")
print("Media: {}".format(mean))
print("Varianza: {}".format(var))
print("Asimetría: {}".format(skew))
print("Curtosis: {}".format(kurt))


# histograma
count, bins, ignored = plt.hist(x=vals_gamma, bins=30, density=True)

# densidad
nobs = 10000
xmin = min(vals_gamma)
xmax = max(vals_gamma)
step = (xmax-xmin)/nobs
x= np.arange(xmin,xmax,step)
plt.plot(x, fitted_var.pdf(x))

plt.title('Histograma y densidad')
plt.xlabel('Valores')
plt.ylabel('Densidad')
plt.show()
# Out:
# Parámetros de la distribución gamma ajustada
# a: 1.8672987100642828
# Localización: 0.9816325554553522
# Escala: 1.019177591708535
#
# Momentos de la distribución gamma ajustada
# Media: 2.884741557779122
# Varianza: 1.9396060497471725
# Asimetría: 1.4636023464117487
# Curtosis: 3.2131977426329645

# %% [markdown]
# ## Distribución Beta
#
# Repetimos el ejercicio anterior con una distribución Beta.

# %%
import numpy as np
from scipy.stats import beta
n=1000
a=1
b = 0.4
vals_beta = beta.rvs(a=a,b=b,size=n)

# %%
import matplotlib.pyplot as plt
from scipy.stats import beta
# histograma
count, bins, ignored = plt.hist(x=vals_beta, bins=30, density=True)

# densidad
nobs = 10000
xmin = min(vals_beta)
xmax = max(vals_beta)
step = (xmax-xmin)/nobs
x= np.arange(xmin,xmax,step)

x= np.arange(0,1,0.01)
plt.plot(x, beta.pdf(x, a=a,b=b))

plt.title('Histograma y densidad b=3')
plt.xlabel('Valores')
plt.ylabel('Densidad')
plt.show()

# %%
mean, var, skew, kurt = beta.stats(a=a,b=b, moments='mvsk')
print("Media: {}".format(mean))
print("Varianza: {}".format(var))
print("Asimetría: {}".format(skew))
print("Curtosis: {}".format(kurt))
# Out:
# Media: 0.7142857142857143
# Varianza: 0.0850340136054422
# Asimetría: -0.8645257915705333
# Curtosis: -0.4973262032085561

# %%
import matplotlib.pyplot as plt
from scipy.stats import beta
# ajuste de datos a una beta - obtener parámetros
fa, fb, floc, fscale = beta.fit(vals_beta)
print("Parámetros de la distribución beta ajustada")
print("a: {}".format(fa))
print("b: {}".format(fb))
print("Localización: {}".format(floc))
print("Escala: {}".format(fscale))

# variable ajustada 
fitted_var = beta.freeze(a=fa, b=fb, loc=floc,scale=fscale)
# momentos de la variable ajustada
mean, var, skew, kurt = fitted_var.stats(moments='mvsk')
print("\nMomentos de la distribución beta ajustada")
print("Media: {}".format(mean))
print("Varianza: {}".format(var))
print("Asimetría: {}".format(skew))
print("Curtosis: {}".format(kurt))


# histograma
count, bins, ignored = plt.hist(x=vals_beta, bins=30, density=True)

# densidad
nobs = 10000
xmin = min(vals_beta)
xmax = max(vals_beta)
step = (xmax-xmin)/nobs
x= np.arange(xmin,xmax,step)
plt.plot(x, fitted_var.pdf(x))

plt.title('Histograma y densidad')
plt.xlabel('Valores')
plt.ylabel('Densidad')
plt.show()
# Out:
# Parámetros de la distribución beta ajustada
# a: 1.0152646368615676
# b: 0.4164870752213419
# Localización: -0.002620999282310039
# Escala: 1.0026209992819153
#
# Momentos de la distribución beta ajustada
# Media: 0.7083442024039932
# Varianza: 0.08527068036190787
# Asimetría: -0.8368524178529182
# Curtosis: -0.5404191119082651

# %% [markdown]
# ## Distribución Lognormal
#
# Repetimos el ejercicio anterior con una distribución Lognormal.

# %%
import math
import numpy as np
from scipy.stats import lognorm
n=1000
loc=0
sigma = 1.4
vals_lognormal = lognorm.rvs(s=sigma, loc=loc, size=n)

# %%
import matplotlib.pyplot as plt
from scipy.stats import lognorm
import math
# histograma
count, bins, ignored = plt.hist(x=vals_lognormal, bins=40, density=True)
plt.title('Histograma con parámetros (0,1.4)')

# densidad
#Sigma es la desviación estándar de la distribución logarítmica normal, y es igual a sqrt (ln (1 + varianza / media ^ 2)).
# Out:
# Text(0.5, 1.0, 'Histograma con parámetros (0,1.4)')

# %%
mean, var, skew, kurt = lognorm.stats(s=sigma, loc=loc, moments='mvsk')
print("Media: {}".format(mean))
print("Varianza: {}".format(var))
print("Asimetría: {}".format(skew))
print("Curtosis: {}".format(kurt))
# Out:
# Media: 2.664456241929417
# Varianza: 43.301117712908834
# Asimetría: 22.472440366881578
# Curtosis: 3401.024651578727

# %%
import matplotlib.pyplot as plt
from scipy.stats import lognorm
# ajuste de datos a una lognormal - obtener parámetros
fs, floc, fscale = lognorm.fit(vals_lognormal)
print("Parámetros de la distribución lognormal ajustada")
print("s: {}".format(fs))
print("Localización: {}".format(floc))
print("Escala: {}".format(fscale))

# variable ajustada 
fitted_var = lognorm.freeze(s=fs, loc=floc,scale=fscale)
# momentos de la variable ajustada
mean, var, skew, kurt = fitted_var.stats(moments='mvsk')
print("\nMomentos de la distribución lognormal ajustada")
print("Media: {}".format(mean))
print("Varianza: {}".format(var))
print("Asimetría: {}".format(skew))
print("Curtosis: {}".format(kurt))


# histograma
count, bins, ignored = plt.hist(x=vals_lognormal, bins=30, density=True)

# densidad
nobs = 10000
xmin = min(vals_lognormal)
xmax = max(vals_lognormal)
step = (xmax-xmin)/nobs
x= np.arange(xmin,xmax,step)
plt.plot(x, fitted_var.pdf(x))

plt.title('Histograma y densidad')
plt.xlabel('Valores')
plt.ylabel('Densidad')
plt.show()
# Out:
# Parámetros de la distribución lognormal ajustada
# s: 1.4284359746509092
# Localización: -0.002355953303957114
# Escala: 1.0319783303199719
#
# Momentos de la distribución lognormal ajustada
# Media: 2.8601353648756307
# Varianza: 54.84895257695028
# Asimetría: 25.08066530195009
# Curtosis: 4586.690032622534

# %% [markdown]
# ## Distribución Weibull
#
# Repetimos el ejercicio anterior con una distribución Weibull.

# %%
import math
import numpy as np
from scipy.stats import weibull_min
n=1000
c=20
loc = 1
vals_weibull = weibull_min.rvs(c=c, loc=loc, size=n)

# %%
import matplotlib.pyplot as plt
from scipy.stats import weibull_min
# histograma
count, bins, ignored = plt.hist(x=vals_weibull, bins=30, density=True)

# densidad
nobs = 10000
xmin = min(vals_weibull)
xmax = max(vals_weibull)
step = (xmax-xmin)/nobs
x= np.arange(xmin,xmax,step)
plt.plot(x, weibull_min.pdf(x, c=c, loc=loc))


plt.title('Histograma y densidad c=20')
plt.xlabel('Valores')
plt.ylabel('Densidad')
plt.show()

# %%
mean, var, skew, kurt = weibull_min.stats(c=c, loc=loc, moments='mvsk')
print("Media: {}".format(mean))
print("Varianza: {}".format(var))
print("Asimetría: {}".format(skew))
print("Curtosis: {}".format(kurt))
# Out:
# Media: 1.9735042655627757
# Varianza: 0.0036402147979540667
# Asimetría: -0.8679650951765687
# Curtosis: 1.2672007593494596

# %%
import matplotlib.pyplot as plt
from scipy.stats import weibull_min
# ajuste de datos a una Weibull - obtener parámetros
fc, floc, fscale = weibull_min.fit(vals_weibull)
print("Parámetros de la distribución Weibull ajustada")
print("c: {}".format(fc))
print("Localización: {}".format(floc))
print("Escala: {}".format(fscale))

# variable ajustada 
fitted_var = weibull_min.freeze(c=fc, loc=floc,scale=fscale)
# momentos de la variable ajustada
mean, var, skew, kurt = fitted_var.stats(moments='mvsk')
print("\nMomentos de la distribución Weibull ajustada")
print("Media: {}".format(mean))
print("Varianza: {}".format(var))
print("Asimetría: {}".format(skew))
print("Curtosis: {}".format(kurt))


# histograma
count, bins, ignored = plt.hist(x=vals_weibull, bins=30, density=True)

# densidad
nobs = 10000
xmin = min(vals_weibull)
xmax = max(vals_weibull)
step = (xmax-xmin)/nobs
x= np.arange(xmin,xmax,step)
plt.plot(x, fitted_var.pdf(x))

plt.title('Histograma y densidad')
plt.xlabel('Valores')
plt.ylabel('Densidad')
plt.show()
# Out:
# Parámetros de la distribución Weibull ajustada
# c: 24.346682690859637
# Localización: 0.8162558055156566
# Escala: 1.1854803908805582
#
# Momentos de la distribución Weibull ajustada
# Media: 1.9755372881195092
# Varianza: 0.0035237740740312
# Asimetría: -0.9129535548813474
# Curtosis: 1.430520954420314

# %% [markdown]
# # Distribución CrystalBall

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import crystalball

# Generate random values from the Crystalball distribution with beta=2 and m=3
beta = 0.5
m = 9
vals_crystalball = crystalball.rvs(beta, m, size=1000)

# Create a histogram
count, bins, ignored = plt.hist(x=vals_crystalball, bins=30, density=True, alpha=0.6, label='Histogram')

# Calculate the probability density function for the Crystalball distribution
nobs = 10000
xmin = min(vals_crystalball)
xmax = max(vals_crystalball)
step = (xmax - xmin) / nobs
x = np.arange(xmin, xmax, step)
pdf = crystalball.pdf(x, beta, m)
plt.plot(x, pdf, 'r', lw=2, label='PDF (Crystalball)')

plt.title(f'Histogram and Crystalball PDF (beta={beta}, m={m})')
plt.xlabel('Values')
plt.ylabel('Density')
plt.legend()
plt.show()


mean, var, skew, kurt = crystalball.stats(beta, m, moments='mvsk')
print("Media: {}".format(mean))
print("Varianza: {}".format(var))
# Out:
# Media: -1.4026316436097643
# Varianza: 8.124304808793969
