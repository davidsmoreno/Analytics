# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df_orders=pd.read_csv('challenge_orders.csv')
df_analytics=pd.read_csv('challenge_analytics.csv')

# %%
df_analytics.head()
# Out:
#    Unnamed: 0                         TIMESTAMP    SESSION_ID  \
# 0           0  2019-04-16 17:23:54.892000+00:00  1.555435e+12
# 1           1  2019-04-15 21:08:01.644000-07:00  1.555362e+12
# 2           2  2019-04-16 20:48:59.590000-07:00  1.555448e+12
# 3           3  2019-04-16 01:11:25.613000-07:00  1.555377e+12
# 4           4  2019-04-15 22:26:03.508000-07:00  1.555367e+12
#
#                  EVENT_TYPE PLATFORM              EVENT_SOURCE   KEYWORD  \
# 0           view_store_type  Android                    MARKET       NaN
# 1  view_product_description  Android              LOCAL_SEARCH       NaN
# 2              local_search      iOS                     TYPED       zop
# 3               add_to_cart      iOS  VIEW_PRODUCT_DESCRIPTION       NaN
# 4              local_search      iOS                     TYPED  lentejas
#
#                      OBJ_ID  obsf_user_id  OBSF_USER_ID  OBSF_STORE_TYPE
# 0                       NaN             0             0                0
# 1  5cb4f279ee88fc0015b411d6             1             1                1
# 2                       NaN             2             2                2
# 3                       NaN             3             3                3
# 4                       NaN             4             4                1

# %%
df_analytics.corr()
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_32352\3798085954.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_analytics.corr()
#                  Unnamed: 0  SESSION_ID  obsf_user_id  OBSF_USER_ID  \
# Unnamed: 0         1.000000   -0.000638      0.070689      0.070689
# SESSION_ID        -0.000638    1.000000     -0.000153     -0.000153
# obsf_user_id       0.070689   -0.000153      1.000000      1.000000
# OBSF_USER_ID       0.070689   -0.000153      1.000000      1.000000
# OBSF_STORE_TYPE   -0.000976   -0.004430      0.053378      0.053378
#
#                  OBSF_STORE_TYPE
# Unnamed: 0             -0.000976
# SESSION_ID             -0.004430
# obsf_user_id            0.053378
# OBSF_USER_ID            0.053378
# OBSF_STORE_TYPE         1.000000

# %%
df_analytics=df_analytics.drop_duplicates()

# %%
correlation = df_analytics['OBSF_USER_ID'].corr(df_analytics['obsf_user_id'])
correlation
# Out:
# 1.0

# %% [markdown]
# La correlación es uno podemos quitar esta columna, ya que tenemos los mismos datos en obsf_user_id

# %%
df_analytics = df_analytics.drop('OBSF_USER_ID', axis=1)

# %%
df_analytics.head()
# Out:
#    Unnamed: 0                         TIMESTAMP    SESSION_ID  \
# 0           0  2019-04-16 17:23:54.892000+00:00  1.555435e+12
# 1           1  2019-04-15 21:08:01.644000-07:00  1.555362e+12
# 2           2  2019-04-16 20:48:59.590000-07:00  1.555448e+12
# 3           3  2019-04-16 01:11:25.613000-07:00  1.555377e+12
# 4           4  2019-04-15 22:26:03.508000-07:00  1.555367e+12
#
#                  EVENT_TYPE PLATFORM              EVENT_SOURCE   KEYWORD  \
# 0           view_store_type  Android                    MARKET       NaN
# 1  view_product_description  Android              LOCAL_SEARCH       NaN
# 2              local_search      iOS                     TYPED       zop
# 3               add_to_cart      iOS  VIEW_PRODUCT_DESCRIPTION       NaN
# 4              local_search      iOS                     TYPED  lentejas
#
#                      OBJ_ID  obsf_user_id  OBSF_STORE_TYPE
# 0                       NaN             0                0
# 1  5cb4f279ee88fc0015b411d6             1                1
# 2                       NaN             2                2
# 3                       NaN             3                3
# 4                       NaN             4                1

# %% [markdown]
# ### Basic Statistics

# %%
df_analytics.describe()
# Out:
#           Unnamed: 0    SESSION_ID   obsf_user_id  OBSF_STORE_TYPE
# count  489258.000000  4.892580e+05  489258.000000    489258.000000
# mean   244628.500000  1.555390e+12    7811.272829         9.248756
# std    141236.763338  5.165779e+07    6825.181830        11.641779
# min         0.000000  1.554602e+12       0.000000         0.000000
# 25%    122314.250000  1.555355e+12    2283.000000         1.000000
# 50%    244628.500000  1.555376e+12    5740.000000         6.000000
# 75%    366942.750000  1.555440e+12   11661.000000        13.000000
# max    489257.000000  1.556510e+12   29518.000000       142.000000

# %% [markdown]
# ## distribution of Categorical Variables:

# %%
# Plot distribution of event types
plt.figure(figsize=(10, 6))
sns.countplot(data=df_analytics, x='EVENT_TYPE')
plt.xticks(rotation=45)
plt.title('Distribution of Event Types')
plt.show()

# %%
df_analytics=pd.read_csv('challenge_analytics.csv')
df_analytics['TIMESTAMP'] = pd.to_datetime(df_analytics['TIMESTAMP'], utc=True)
df_analytics.set_index('TIMESTAMP', inplace=True)

# %%
daily_event_counts = df_analytics.resample('D')['EVENT_TYPE'].count()

# Iterate through each day and plot events per hour
for day, count in daily_event_counts.iteritems():
    events_per_hour = df_analytics[day.strftime('%Y-%m-%d')].resample('H')['EVENT_TYPE'].count()

    plt.figure(figsize=(12, 6))
    events_per_hour.plot(kind='bar', color='skyblue')
    plt.title(f'Events Per Hour on {day.date()}')
    plt.xlabel('Time Interval')
    plt.ylabel('Number of Events')
    plt.xticks(rotation=45)
    plt.show()
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_4940\3121642100.py:4: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for day, count in daily_event_counts.iteritems():
# C:\Users\David\AppData\Local\Temp\ipykernel_4940\3121642100.py:5: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   events_per_hour = df_analytics[day.strftime('%Y-%m-%d')].resample('H')['EVENT_TYPE'].count()
# C:\Users\David\AppData\Local\Temp\ipykernel_4940\3121642100.py:5: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   events_per_hour = df_analytics[day.strftime('%Y-%m-%d')].resample('H')['EVENT_TYPE'].count()
# C:\Users\David\AppData\Local\Temp\ipykernel_4940\3121642100.py:5: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   events_per_hour = df_analytics[day.strftime('%Y-%m-%d')].resample('H')['EVENT_TYPE'].count()

# %%
df_analytics['Time'] = df_analytics.index.time
time_intervals = df_analytics['Time'].apply(
    lambda x: (x.hour * 60 + x.minute) // 120
)
event_counts = df_analytics.groupby(time_intervals).size()

# Define time interval labels
time_interval_labels = [f'{i*2:02}:00 - {(i+1)*2:02}:00' for i in event_counts.index]

# Plot events per 2-hour interval
plt.figure(figsize=(12, 6))
event_counts.plot(kind='bar', color='skyblue')
plt.title('Events Per 2-Hour Interval (Time-based)')
plt.xlabel('Time Interval')
plt.ylabel('Number of Events')
plt.xticks(rotation=45, ticks=event_counts.index, labels=time_interval_labels)
plt.show()

# %% [markdown]
# ### Platform

# %%
platform_counts = df_analytics['PLATFORM'].value_counts()

# Plot platform distribution
plt.figure(figsize=(8, 6))
sns.barplot(x=platform_counts.index, y=platform_counts.values, palette='viridis')
plt.title('Distribution of Events by Platform')
plt.xlabel('PLATFORM')
plt.ylabel('Number of Events')
plt.xticks(rotation=45)
plt.show()

# %%
pivot_table = df_analytics.pivot_table(index='EVENT_SOURCE', columns='EVENT_TYPE', values='PLATFORM', aggfunc='count', fill_value=0)

# Plotting a heatmap to show the relationship numerically with units
plt.figure(figsize=(10, 6))
sns.heatmap(pivot_table, annot=True, cmap='YlGnBu', fmt='d')  # Using 'd' for integer formatting
plt.title('Relationship between EVENT_SOURCE and EVENT_TYPE')
plt.xlabel('Event Type')
plt.ylabel('Event Source')
plt.show()

# %%
pivot_table
# Out:
# EVENT_TYPE                   add_to_cart  local_search  \
# EVENT_SOURCE
# BANNER                            1124.0           NaN
# BASKET                               NaN           NaN
# BRANDROOM                            2.0           NaN
# CHECKOUT                             NaN           NaN
# COMPLEMENTARY_PRODUCT               45.0           NaN
# CORRIDOR_LANE                    12584.0           NaN
# DEEPLINK                          1079.0           NaN
# FAVORITES_TAB                       11.0           NaN
# HOME                                 NaN           NaN
# HOME_MARKET                      11623.0           NaN
# HOME_MARKET_LOWER                   16.0           NaN
# HOME_SEARCH                        777.0           NaN
# LOCAL_SEARCH                     20461.0           NaN
# LOCAL_SEARCH_WITHOUT_SEARCH          7.0           NaN
# MAIN_STORES                          NaN           NaN
# MARKET                               NaN           NaN
# MARKET_PREVIOUS_ORDER              298.0           NaN
# MARKET_WHIM                        601.0           NaN
# MY_FAVORITES                      3052.0           NaN
# MY_LAST_ORDERS                     484.0           NaN
# ORDER_HISTORY_MARKET_HOME            NaN           NaN
# ORDER_SUMMARY                        NaN           NaN
# POPULAR_SEARCHES                     NaN        3283.0
# PRODUCT_DESCRIPTION_SEARCH           4.0           NaN
# PROMOTIONS                           NaN           NaN
# RECENTLY_ADDED                      77.0           NaN
# RECENT_SEARCHES                      3.0           NaN
# RECOMMENDATION                     127.0           NaN
# RECOMMENDED                         34.0           NaN
# RELATED_PRODUCT                      NaN           NaN
# RELATIONED_PRODUCT                 117.0           NaN
# SHARKS                             464.0           NaN
# SUB_STORE_TYPE                       NaN           NaN
# SUGGESTED                            NaN       32574.0
# TOP_QUERY                            NaN        1001.0
# TYPED                                NaN       82665.0
# VIEW_PRODUCT_DESCRIPTION          9263.0           NaN
# coupon                             350.0           NaN
#
# EVENT_TYPE                   order_placed_confirmed  select_store_type  \
# EVENT_SOURCE
# BANNER                                          NaN                NaN
# BASKET                                          NaN                NaN
# BRANDROOM                                       NaN                NaN
# CHECKOUT                                     6160.0                NaN
# COMPLEMENTARY_PRODUCT                           NaN                NaN
# CORRIDOR_LANE                                   NaN                NaN
# DEEPLINK                                        NaN                NaN
# FAVORITES_TAB                                   NaN                NaN
# HOME                                            NaN            37924.0
# HOME_MARKET                                     NaN                NaN
# HOME_MARKET_LOWER                               NaN                NaN
# HOME_SEARCH                                     NaN                NaN
# LOCAL_SEARCH                                    NaN                NaN
# LOCAL_SEARCH_WITHOUT_SEARCH                     NaN                NaN
# MAIN_STORES                                     NaN             6311.0
# MARKET                                          NaN            53058.0
# MARKET_PREVIOUS_ORDER                           NaN                NaN
# MARKET_WHIM                                     NaN                NaN
# MY_FAVORITES                                    NaN                NaN
# MY_LAST_ORDERS                                  NaN                NaN
# ORDER_HISTORY_MARKET_HOME                       NaN                NaN
# ORDER_SUMMARY                                   NaN                NaN
# POPULAR_SEARCHES                                NaN                NaN
# PRODUCT_DESCRIPTION_SEARCH                      NaN                NaN
# PROMOTIONS                                      NaN                NaN
# RECENTLY_ADDED                                  NaN                NaN
# RECENT_SEARCHES                                 NaN                NaN
# RECOMMENDATION                                  NaN                NaN
# RECOMMENDED                                     NaN                NaN
# RELATED_PRODUCT                                 NaN                NaN
# RELATIONED_PRODUCT                              NaN                NaN
# SHARKS                                          NaN                NaN
# SUB_STORE_TYPE                                  NaN              528.0
# SUGGESTED                                       NaN                NaN
# TOP_QUERY                                       NaN                NaN
# TYPED                                           NaN                NaN
# VIEW_PRODUCT_DESCRIPTION                        NaN                NaN
# coupon                                          NaN                NaN
#
# EVENT_TYPE                   view_product_description  view_store_type
# EVENT_SOURCE
# BANNER                                          102.0             75.0
# BASKET                                         1073.0              NaN
# BRANDROOM                                         6.0              NaN
# CHECKOUT                                          NaN              NaN
# COMPLEMENTARY_PRODUCT                            63.0              NaN
# CORRIDOR_LANE                                 14946.0              NaN
# DEEPLINK                                         41.0              NaN
# FAVORITES_TAB                                     NaN              NaN
# HOME                                              NaN          28013.0
# HOME_MARKET                                   15320.0              NaN
# HOME_MARKET_LOWER                                 NaN              NaN
# HOME_SEARCH                                     400.0              NaN
# LOCAL_SEARCH                                  19565.0              NaN
# LOCAL_SEARCH_WITHOUT_SEARCH                       NaN              NaN
# MAIN_STORES                                       NaN           5784.0
# MARKET                                            NaN         103462.0
# MARKET_PREVIOUS_ORDER                            38.0              NaN
# MARKET_WHIM                                       NaN              NaN
# MY_FAVORITES                                   1632.0              NaN
# MY_LAST_ORDERS                                   14.0              NaN
# ORDER_HISTORY_MARKET_HOME                         2.0              NaN
# ORDER_SUMMARY                                   254.0              NaN
# POPULAR_SEARCHES                                  NaN              NaN
# PRODUCT_DESCRIPTION_SEARCH                        NaN              NaN
# PROMOTIONS                                      215.0              NaN
# RECENTLY_ADDED                                  168.0              NaN
# RECENT_SEARCHES                                   1.0              NaN
# RECOMMENDATION                                    NaN              NaN
# RECOMMENDED                                     360.0              NaN
# RELATED_PRODUCT                                1281.0              NaN
# RELATIONED_PRODUCT                              151.0              NaN
# SHARKS                                          201.0              NaN
# SUB_STORE_TYPE                                    NaN              3.0
# SUGGESTED                                         NaN              NaN
# TOP_QUERY                                         NaN              NaN
# TYPED                                             NaN              NaN
# VIEW_PRODUCT_DESCRIPTION                        745.0              NaN
# coupon                                            NaN              NaN

# %% [markdown]
# ## Most common keywords

# %%
# Plot top keywords
plt.figure(figsize=(10, 6))
df_analytics['KEYWORD'].value_counts().head(10).plot(kind='bar')
plt.title('Top Searched Keywords')
plt.ylabel('Frequency')
plt.xlabel('Keyword')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Correlación entre variables, vemos que no hay ninguna que se correlacione linealmente

# %%
df_analytics.corr()
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_32352\3798085954.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_analytics.corr()
#                  Unnamed: 0  SESSION_ID  obsf_user_id  OBSF_STORE_TYPE
# Unnamed: 0         1.000000   -0.000638      0.070689        -0.000976
# SESSION_ID        -0.000638    1.000000     -0.000153        -0.004430
# obsf_user_id       0.070689   -0.000153      1.000000         0.053378
# OBSF_STORE_TYPE   -0.000976   -0.004430      0.053378         1.000000

# %% [markdown]
# ## Distribución de los datos numericos

# %%
df_analytics.hist()
# Out:
# array([[<Axes: title={'center': 'Unnamed: 0'}>,
#         <Axes: title={'center': 'SESSION_ID'}>],
#        [<Axes: title={'center': 'obsf_user_id'}>,
#         <Axes: title={'center': 'OBSF_STORE_TYPE'}>]], dtype=object)

# %% [markdown]
# ## Orders

# %%
df_orders.head()
# Out:
#    Unnamed: 0  ORDER_ID  PRODUCT_ID PAYMENT_METHOD  TOTAL_VALUE  \
# 0           0  35394843  2090144731           cash       1940.0
# 1           1  35419116  2090144731             cc       8900.0
# 2           2  35404241  2090144731           cash        150.0
# 3           3  35405366  2090144731           cash        400.0
# 4           4  35406544  2090144731           cash       9580.0
#
#                   CREATED_AT  STORE_TO_USER_DISTANCE  OBSF_USER_ID  \
# 0  2019-04-15 13:40:19+00:00                   488.0          8540
# 1  2019-04-16 20:54:24+00:00                  4761.0          3990
# 2  2019-04-15 21:12:49+00:00                  3141.0         19052
# 3  2019-04-15 21:58:28+00:00                  3070.0         16978
# 4  2019-04-15 23:36:01+00:00                  1210.0          9521
#
#    OBSF_STORE_TYPE
# 0                5
# 1               14
# 2                5
# 3               14
# 4                5

# %%
df_orders = pd.read_csv('challenge_orders.csv')

df_orders['CREATED_AT'] = pd.to_datetime(df_orders['CREATED_AT'])

df_orders['CREATED_AT'] = pd.to_datetime(df_orders['CREATED_AT'])

# Extract only the time component from 'CREATED_AT'
df_orders['TIME'] = df_orders['CREATED_AT'].dt.time

# Define time ranges
time_ranges = [
    (pd.to_datetime('07:00:00').time(), pd.to_datetime('09:00:00').time(), '7-9 am'),
    (pd.to_datetime('09:00:00').time(), pd.to_datetime('11:00:00').time(), '9-11 am'),
    (pd.to_datetime('11:00:00').time(), pd.to_datetime('13:00:00').time(), '11-1 pm'),
    (pd.to_datetime('13:00:00').time(), pd.to_datetime('15:00:00').time(), '1-3 pm'),
    (pd.to_datetime('15:00:00').time(), pd.to_datetime('17:00:00').time(), '3-5 pm'),
    (pd.to_datetime('17:00:00').time(), pd.to_datetime('19:00:00').time(), '5-7 pm'),
    (pd.to_datetime('19:00:00').time(), pd.to_datetime('21:00:00').time(), '7-9 pm')
]

# Function to assign time category
def assign_time_category(time):
    for start, end, category in time_ranges:
        if start <= time < end:
            return category
    return 'Other'

# Apply the function to create the new categorical variable
df_orders['TIME_CATEGORY'] = df_orders['TIME'].apply(assign_time_category)

# Plot the bar plot of the new time category variable
plt.figure(figsize=(10, 6))
sns.countplot(data=df_orders, x='TIME_CATEGORY')
plt.title('Order Count by Time Category')
plt.xlabel('Time Category')
plt.ylabel('Order Count')
plt.xticks(rotation=45)
plt.show()

# %%
df_orders['TIME_CATEGORY'] = df_orders['TIME'].apply(assign_time_category)

# Plot the bar plot of mean 'TOTAL_VALUE' for each time category
plt.figure(figsize=(10, 6))
sns.barplot(data=df_orders, x='TIME_CATEGORY', y='TOTAL_VALUE', estimator='mean')
plt.title('Mean Total Value by Time Category')
plt.xlabel('Time Category')
plt.ylabel('Mean Total Value')
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df_orders is your DataFrame
df_orders = pd.read_csv('challenge_orders.csv')

# Convert 'CREATED_AT' to datetime
df_orders['CREATED_AT'] = pd.to_datetime(df_orders['CREATED_AT'])

# Extract only the time component from 'CREATED_AT'
df_orders['CREATED_AT'] = df_orders['CREATED_AT'].dt.time

# Exploratory Analysis of 'PAYMENT_METHOD'
plt.figure(figsize=(8, 6))
sns.countplot(data=df_orders, x='PAYMENT_METHOD')
plt.title('Distribution of Payment Methods')
plt.xlabel('Payment Method')
plt.ylabel('Count')
plt.show()

# Exploratory Analysis of 'TOTAL_VALUE'
plt.figure(figsize=(10, 6))
sns.histplot(data=df_orders, x='TOTAL_VALUE', bins=20)
plt.title('Distribution of Total Values')
plt.xlabel('Total Value')
plt.ylabel('Count')
plt.show()
