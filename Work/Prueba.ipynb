# %%
1)


select profesor_name,max(salary) from salaies



5) 


#Tabla a
id
name

##Tabla b
id
A_id 
value

## Queremos hace r un inner join con el id de cada una

select B.id,B.value, A.name from b
inner join on A.id = B.A_id


##Ahora si queremos solo hacer una vista tenemos

Create view vista as
select B.id,B.value, A.name from B
inner join on A.id = B.A_id



##########Punto 6###########

Facturas--SOE_CustInvoiceJourStaging ## Tabla
Tiene DataAreaId,InventLocationId,InvoiceId,CurrencyCode,SalesId,


a) Sumar los valores totales de las facturas 

select DataAreaId,InventLocationId,sum(InvoiceAmount) as T_venta from SOE_CustInvoiceJourStaging
where DataAreaId in ('010','020')
group by DataAreaId,InventLocationId
order by T_venta desc



select DataAreaId,InoiceAccount,sum(SalesBalance+SumTac) as T_Factura
from SOE_CustInvoiceJourStaging
where DataAreaId in ('010','020') and left(InvoiceAccount,1)='X'
group by DataAreaId,InvoiceAccount



select DataAreaId,InoiceAccount,MONTH(InvoiceDate),AVG(InvoiceAmount) as Promedio_Fac
from SOE_CustInvoiceJourStaging
where DataAreaId in ('010','020') and left(InvoiceAccount,1)='X'
group by DataAreaId,InvoiceAccount,MONTH(InvoiceDate)
